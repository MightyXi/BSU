# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("homicide-data.csv")
df.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race victim_age  \
# 0  Alb-000001     20100504.0       GARCIA         JUAN    Hispanic         78
# 1  Alb-000002     20100216.0      MONTOYA      CAMERON    Hispanic         17
# 2  Alb-000003     20100601.0  SATTERFIELD      VIVIANA       White         15
# 3  Alb-000004     20100101.0     MENDIOLA       CARLOS    Hispanic         32
# 4  Alb-000005     20100102.0         MULA       VIVIAN       White         72
#
#   victim_sex         city state        lat         lon            disposition
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
# 2     Female  Albuquerque    NM  35.086092 -106.695568  Closed without arrest
# 3       Male  Albuquerque    NM  35.078493 -106.556094       Closed by arrest
# 4     Female  Albuquerque    NM  35.130357 -106.580986  Closed without arrest

# %%
df = df.replace('Unknown',None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52179 entries, 0 to 52178
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uid            52179 non-null  object
#  1   reported_date  52172 non-null  float64
#  2   victim_last    46407 non-null  object
#  3   victim_first   46410 non-null  object
#  4   victim_race    47973 non-null  object
#  5   victim_age     49173 non-null  float64
#  6   victim_sex     47941 non-null  object
#  7   city           52172 non-null  object
#  8   state          52172 non-null  object
#  9   lat            52112 non-null  float64
#  10  lon            52112 non-null  float64
#  11  disposition    52172 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 4.8+ MB

# %%
df['victim_age'] = pd.to_numeric(df['victim_age'])

# %%
sns.countplot(data=df, x='victim_race')
# Out:
# <Axes: xlabel='victim_race', ylabel='count'>

# %%
df['victim_sex'].value_counts()
df.victim_sex.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='victim_sex'>

# %%
sns.countplot(data=df, x='victim_race', palette='autumn', hue='victim_sex')
# Out:
# <Axes: xlabel='victim_race', ylabel='count'>

# %%
df.victim_age.plot(kind='hist',bins=50,color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(df, x="victim_age", bins=50, hue="victim_sex")

# %%
sns.countplot(data=df, x='disposition')
# Out:
# <Axes: xlabel='disposition', ylabel='count'>

# %%
without_black = df[ df['victim_race'] != 'Black' ]
without_black.victim_age.plot(kind='hist',bins=50,color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(without_black, x="victim_age", bins=50, hue="victim_sex")
